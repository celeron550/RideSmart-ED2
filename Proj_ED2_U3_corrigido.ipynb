# %% [markdown]
# # Questões para discussão
#
# No relatório e na apresentação, responda:
#
# 1. Como o problema foi modelado como grafo?
# - O problema foi modelado como um Grafo Direcionado (Dígrafo) utilizando a biblioteca OSMnx. A malha viária real de Natal foi capturada e convertida em uma estrutura de dados de lista/dicionário de adjacência. Essa estrutura permite representar de forma fiel as regras de trânsito reais, como ruas de mão única, conversões proibidas e retornos.
# 2. O que representam os nós e as arestas?
# - Nós (Vértices): Representam os cruzamentos de vias, bifurcações, esquinas e pontos geométricos de conexão na malha urbana.
# - Arestas (Arcos): Representam os segmentos de ruas e avenidas que conectam esses cruzamentos, possuindo um sentido de direção obrigatório.
# 3. Quais pesos foram usados?
# - Distância (grafo_distancia): O comprimento físico da via medido em metros.
# - Tempo Livre (grafo_tempo): O tempo teórico (em segundos) gasto para percorrer a via baseando-se no limite máximo de velocidade regulamentar.
# - Tempo com Trânsito Realista (grafo_transito): O tempo de viagem calibrado de acordo com uma velocidade média de horário de pico urbano ($20\text{ km/h}$), garantindo sincronia com ferramentas comerciais como o Google Maps.
# 4. Como o trânsito sintético alterou as rotas?
# - A inclusão do trânsito mudou drasticamente o comportamento das rotas. No cenário de tempo livre, o algoritmo tende a escolher caminhos em linha reta por vias locais. Com o trânsito pesado ativado, o algoritmo de caminho mínimo passa a penalizar severamente vias saturadas e redireciona o veículo para rotas que priorizam o fluxo contínuo (como grandes avenidas ou rodovias periféricas), mesmo que o trajeto físico se torne geograficamente mais longo.
# 5. Caminhar alguns metros melhorou a solução?
# - Sim. No experimento prático de Ponta Negra ao Midway Mall, caminhar apenas $61\text{ metros}$ permitiu ao usuário se deslocar até um nó estratégico fora do gargalo local de origem. Isso permitiu que o veículo de aplicativo fizesse o embarque em uma posição muito mais favorável, economizando minutos preciosos que seriam gastos em retornos residenciais lentos ou semáforos de bairros.
# 6. Em quais casos caminhar atrapalhou?
# - Caminhar atrapalha a solução em duas situações principais: Quando o raio máximo de caminhada ($X$) é excessivamente grande: O algoritmo pode sugerir que o usuário caminhe distâncias irreais (ex: mais de $1\text{ km}$ a pé) sob sol ou chuva para poupar uma diferença insignificante de tempo de carro, reduzindo o conforto do serviço de mobilidade. E Origens em vias de fluxo livre: Se o ponto de partida original $A$ já estiver localizado em uma avenida de trânsito rápido e sentido favorável, qualquer caminhada para nós adjacentes apenas adicionará cansaço físico ao usuário sem gerar ganho no trecho de carro.
# 7. A menor distância foi também a rota mais rápida?
# - Não. O teste de validação comprovou que a rota baseada estritamente em menor distância física (metros) força o trajeto por dentro de bairros com muitos cruzamentos e conversões de baixa velocidade. Já a rota baseada em tempo com trânsito priorizou o deslocamento por vias arteriais de maior fluidez, provando que, no cenário urbano, o caminho geometricamente mais curto raramente é o mais rápido.
# 8. O A* expandiu menos nós que o Dijkstra?
# - Sim, drasticamente menos. Enquanto o Dijkstra expande nós de maneira radial e concêntrica (em círculos para todas as direções a partir da origem), o $A^*$ utiliza uma função heurística baseada na distância em linha reta até o destino. Isso dá um "senso de direção" ao algoritmo, fazendo com que ele expanda nós focando quase que exclusivamente na direção geométrica do Midway Mall, reduzindo o espaço de busca e o tempo de processamento.
# 9. O Dijkstra com Heap foi mais eficiente que o Dijkstra simples?
# - Sim, em termos de complexidade de tempo. O Dijkstra simples varre linearmente ($O(V)$) todo o conjunto de nós a cada iteração para descobrir qual possui a menor distância atual. O Dijkstra com Heap utiliza uma Fila de Prioridade (Min-Heap), reduzindo esse custo de busca do menor elemento para $O(\log V)$. Embora o número de nós expandidos no pior caso possa ser similar, o tempo de CPU gasto pela estrutura com Heap é imensamente menor em grafos grandes.
# 10. O algoritmo da literatura trouxe algum ganho?
# - O algoritmo adicional implementado (Dijkstra Bidirecional) trouxe um excelente ganho computacional. Ao disparar duas buscas simultâneas — uma direto da origem e outra reversa do destino — as franjas de busca se encontram no meio do caminho. Isso faz com que a área total de nós explorados seja consideravelmente menor do que uma busca tradicional do Dijkstra que precisa caminhar sozinha por todo o trajeto.
# 11. Quais limitações existem na modelagem proposta?
# - Independência de Arestas: Na primeira versão do trânsito sintético (random.uniform), o trânsito flutuava quarteirão por quarteirão. Na realidade, o trânsito é regionalmente correlacionado (se a Engenheiro Roberto Freire para, todos os quarteirões dela travam em cadeia).
# - Custo da Caminhada Abstrato: O modelo foca apenas em minimizar o tempo que o usuário passa dentro do carro, sem ponderar o "peso psicológico" ou o tempo gasto no deslocamento a pé pelo usuário até o ponto $P$.
# - Grafo Estático: O mapa não sofre atualizações de eventos dinâmicos em tempo real, como acidentes repentinos, obras na pista ou bloqueios temporários.
# 12. Como o modelo poderia ser aproximado de um aplicativo real de mobilidade?
# - Para aproximar este projeto de um sistema comercial como o Uber ou Waze, deveriam ser implementadas as seguintes melhorias:
# - Função de Custo Bi-Objetivo: O algoritmo deveria otimizar uma função combinada, ponderando o tempo de carro e o tempo de caminhada multiplicados por fatores de conveniência (ex: 1 minuto andando "custa" o dobro do que 1 minuto confortavelmente sentado no carro).
# - Fatores de Trânsito Dinâmicos e Coletivos: Substituir as penalidades estáticas ou puramente aleatórias por matrizes de trânsito baseadas em horários históricos (matriz origem-destino por faixa de horário) e velocidade média dos próprios usuários trafegando na via.
# - Restrições de Segurança no Embarque: Adicionar uma camada de filtragem que impeça o ponto de embarque $P$ de ser alocado em locais perigosos, vias de alta velocidade sem acostamento (ex: viadutos ou pontes) ou locais onde a parada de veículos seja proibida por lei.

# %%
# !pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-2.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.3)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.30 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (26.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2026.5.20)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->osmnx) (1.17.0)
# Downloading osmnx-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-2.1.0

# %%
import osmnx as ox
import networkx as nx
G_osm = ox.graph_from_place("Natal, Rio Grande do Norte, Brazil", network_type='drive')
G_osm = ox.add_edge_speeds(G_osm)
G_osm = ox.add_edge_travel_times(G_osm)
G = G_osm
coordenadas = {no: (G_osm.nodes[no]['y'], G_osm.nodes[no]['x']) for no in G_osm.nodes()}

# %%
def dijkstra_simples(grafo, origem, destino):
    distancias = {no: float('inf') for no in grafo}
    distancias[origem] = 0
    visitados = set()
    caminho_anterior = {no: None for no in grafo}
    nos_expandidos = 0

    while len(visitados) < len(grafo):
        # Encontra o noh não visitado com a menor distância atual
        no_atual = None
        menor_distancia = float('inf')
        for no in grafo:
            if no not in visitados and distancias[no] < menor_distancia:
                menor_distancia = distancias[no]
                no_atual = no

        # Se não encontrou um noh alcançável ou chegou ao destino, para
        if no_atual is None or no_atual == destino:
            break

        visitados.add(no_atual)
        nos_expandidos += 1

        # Relaxamento das arestas
        for vizinho, peso in grafo[no_atual].items():
            nova_distancia = distancias[no_atual] + peso
            if nova_distancia < distancias[vizinho]:
                distancias[vizinho] = nova_distancia
                caminho_anterior[vizinho] = no_atual

    # Reconstrói o caminho
    caminho = []
    atual = destino
    while atual is not None:
        caminho.insert(0, atual)
        atual = caminho_anterior[atual]

    if distancias[destino] == float('inf'):
        return None, float('inf'), nos_expandidos # Caminho não encontrado

    return caminho, distancias[destino], nos_expandidos

# %%
import heapq

def dijkstra_heap(grafo, origem, destino):
    distancias = {no: float('inf') for no in grafo}
    distancias[origem] = 0
    # A fila armazena tuplas: (distancia_acumulada, no_atual)
    fila_prioridade = [(0, origem)]
    caminho_anterior = {no: None for no in grafo}
    nos_expandidos = 0

    while fila_prioridade:
        distancia_atual, no_atual = heapq.heappop(fila_prioridade)

        # Se já encontramos um caminho mais curto antes, ignoramos
        if distancia_atual > distancias[no_atual]:
            continue

        nos_expandidos += 1

        if no_atual == destino:
            break

        # Relaxamento das arestas
        for vizinho, peso in grafo[no_atual].items():
            nova_distancia = distancia_atual + peso

            if nova_distancia < distancias[vizinho]:
                distancias[vizinho] = nova_distancia
                caminho_anterior[vizinho] = no_atual
                heapq.heappush(fila_prioridade, (nova_distancia, vizinho))

    # Reconstrói o caminho
    caminho = []
    atual = destino
    while atual is not None:
        caminho.insert(0, atual)
        atual = caminho_anterior[atual]

    if distancias[destino] == float('inf'):
        return None, float('inf'), nos_expandidos # Caminho não encontrado

    return caminho, distancias[destino], nos_expandidos

# %% [markdown]
# A*

# %%
import math
def heuristica_geografica(grafo, no_atual, destino, coordenadas=None, velocidade_kmh=40):
    if coordenadas and no_atual in coordenadas and destino in coordenadas:
        lat1, lon1 = coordenadas[no_atual]
        lat2, lon2 = coordenadas[destino]

        distancia_metros = math.sqrt((lat1 - lat2)**2 + (lon1 - lon2)**2) * 111000

        velocidade_ms = velocidade_kmh / 3.6

        return distancia_metros / velocidade_ms
    return 0

def a_estrela(grafo, origem, destino, coordenadas=None):
    distancias = {no: float('inf') for no in grafo}
    distancias[origem] = 0


    h_inicial = heuristica_geografica(grafo, origem, destino, coordenadas)
    fila_prioridade = [(0 + h_inicial, 0, origem)]

    caminho_anterior = {no: None for no in grafo}
    nos_expandidos = 0
    visitados = set()

    while fila_prioridade:
        f_atual, g_atual, no_atual = heapq.heappop(fila_prioridade)

        if no_atual in visitados:
            continue

        visitados.add(no_atual)
        nos_expandidos += 1

        if no_atual == destino:
            break

        for vizinho, peso in grafo[no_atual].items():
            novo_g = g_atual + peso

            if novo_g < distancias[vizinho]:
                distancias[vizinho] = novo_g
                caminho_anterior[vizinho] = no_atual
                f_score = novo_g + heuristica_geografica(grafo, vizinho, destino, coordenadas)
                heapq.heappush(fila_prioridade, (f_score, novo_g, vizinho))

    caminho = []
    atual = destino
    while atual is not None:
        caminho.insert(0, atual)
        atual = caminho_anterior[atual]

    if distancias[destino] == float('inf'):
        return None, float('inf'), nos_expandidos

    return caminho, distancias[destino], nos_expandidos

# %% [markdown]
# Dijkstra Bidirecional

# %%
import heapq

def DijkstraBidirecional(grafo, grafo_reverso, origem, destino):
    if origem == destino:
        return [origem], 0

    dist_f = {no: float('inf') for no in grafo}
    dist_b = {no: float('inf') for no in grafo}

    pai_f = {origem: None}
    pai_b = {destino: None}

    dist_f[origem] = 0
    dist_b[destino] = 0

    pq_f = [(0, origem)]
    pq_b = [(0, destino)]

    processado_f = set()
    processado_b = set()

    mu = float('inf')
    no_encontrado = None

    while pq_f and pq_b:
        if pq_f[0][0] + pq_b[0][0] >= mu:
            break
        d_f, u = heapq.heappop(pq_f)
        if u in processado_f:
            continue
        processado_f.add(u)

        for v, peso in grafo.get(u, []):
            nova_dist = dist_f[u] + peso
            if nova_dist < dist_f.get(v, float('inf')):
                dist_f[v] = nova_dist
                pai_f[v] = u
                heapq.heappush(pq_f, (nova_dist, v))
                if v in processado_b:
                    dist_total = dist_f[v] + dist_b[v]
                    if dist_total < mu:
                        mu = dist_total
                        no_encontrado = v

        d_b, u_rev = heapq.heappop(pq_b)
        if u_rev in processado_b:
            continue
        processado_b.add(u_rev)

        for w, peso in grafo_reverso.get(u_rev, []):
            nova_dist = dist_b[u_rev] + peso
            if nova_dist < dist_b.get(w, float('inf')):
                dist_b[w] = nova_dist
                pai_b[w] = u_rev
                heapq.heappush(pq_b, (nova_dist, w))
                if w in processado_f:
                    dist_total = dist_f[w] + dist_b[w]
                    if dist_total < mu:
                        mu = dist_total
                        no_encontrado = w

    if mu == float('inf'):
        return None, float('inf')

    caminho = []

    atual = no_encontrado
    while atual is not None:
        caminho.append(atual)
        atual = pai_f.get(atual)
    caminho.reverse()

    atual = pai_b.get(no_encontrado)
    while atual is not None:
        caminho.append(atual)
        atual = pai_b.get(atual)

    return caminho, mu

# %%
# 2. CONSTRUINDO OS GRAFOS COMO DICIONÁRIOS {vizinho: peso}
print("Construindo os grafos de distância, tempo livre e tempo com trânsito...")

grafo_dist      = {no: {} for no in G.nodes()}
grafo_rev_dist  = {no: {} for no in G.nodes()}
grafo_tempo     = {no: {} for no in G.nodes()}
grafo_rev_tempo = {no: {} for no in G.nodes()}
grafo_tempo_livre     = {no: {} for no in G.nodes()}
grafo_rev_tempo_livre = {no: {} for no in G.nodes()}

PENALIDADE_CRUZAMENTO = 15  # segundos adicionados por aresta (trânsito sintético base)

for u, v, dados in G.edges(data=True):
    # --- MÉTRICA 1: DISTÂNCIA FÍSICA ---
    distancia = dados.get('length', 1.0)
    if v not in grafo_dist[u] or distancia < grafo_dist[u][v]:
        grafo_dist[u][v]     = distancia
        grafo_rev_dist[v][u] = distancia

    # --- MÉTRICA 2: TEMPO SEM TRÂNSITO (TEMPO LIVRE) ---
    # Usa apenas o travel_time base original da via
    tempo_base = dados.get('travel_time', 1.0)
    if v not in grafo_tempo_livre[u] or tempo_base < grafo_tempo_livre[u][v]:
        grafo_tempo_livre[u][v]     = tempo_base
        grafo_rev_tempo_livre[v][u] = tempo_base

    # --- MÉTRICA 3: TEMPO COM TRÂNSITO SINTÉTICO ---
    peso_tempo = tempo_base + PENALIDADE_CRUZAMENTO

    tipo_via = dados.get('highway', '')
    if isinstance(tipo_via, list):
        tipo_via = tipo_via[0]

    if tipo_via in ['primary', 'secondary', 'trunk']:
        peso_tempo *= 1.6
    elif tipo_via == 'residential':
        peso_tempo *= 1.2

    if v not in grafo_tempo[u] or peso_tempo < grafo_tempo[u][v]:
        grafo_tempo[u][v]     = peso_tempo
        grafo_rev_tempo[v][u] = peso_tempo

print("✅ Grafos de distância, tempo livre e tempo com trânsito construídos com sucesso.")
print(f"   Nós: {len(G.nodes())} | Arestas: {len(G.edges())}")
# Out:
# Construindo os grafos de distância, tempo livre e tempo com trânsito...
# ✅ Grafos de distância, tempo livre e tempo com trânsito construídos com sucesso.
#    Nós: 18578 | Arestas: 48183

# %% [markdown]
# # RideSmart — Definição de Origem, Destino e Raio de Caminhada
#
# Preencha os campos abaixo com o endereço de origem, o endereço de destino e a distância
# máxima (em metros) que você está disposto a caminhar até o ponto de embarque.

# %%
# ============================================================
# CONFIGURAÇÃO DO RIDESMART — EDITE OS VALORES ABAIXO
# ============================================================

endereco_origem  = input("Endereço de ORIGEM  (ex: Midway Mall, Natal, Brazil): ").strip()
endereco_destino = input("Endereço de DESTINO (ex: Partage Norte Shopping, Natal, Brazil): ").strip()
raio_caminhada   = float(input("Distância máxima de CAMINHADA em metros (ex: 500): ").strip())

# Geocodifica e encontra os nós no grafo
print("\nBuscando coordenadas...")
coord_A = ox.geocode(endereco_origem)
coord_B = ox.geocode(endereco_destino)

no_A = ox.distance.nearest_nodes(G_osm, X=coord_A[1], Y=coord_A[0])
no_B = ox.distance.nearest_nodes(G_osm, X=coord_B[1], Y=coord_B[0])

print(f"✅ Origem  : {endereco_origem}")
print(f"   → nó OSM: {no_A}  (lat={coord_A[0]:.5f}, lon={coord_A[1]:.5f})")
print(f"✅ Destino : {endereco_destino}")
print(f"   → nó OSM: {no_B}  (lat={coord_B[0]:.5f}, lon={coord_B[1]:.5f})")
print(f"✅ Raio máx de caminhada: {raio_caminhada:.0f} m")
# Out:
# Endereço de ORIGEM  (ex: Midway Mall, Natal, Brazil): Midway Mall, Natal, Brazil
# Endereço de DESTINO (ex: Partage Norte Shopping, Natal, Brazil): praia shopping, Natal, brazil
# Distância máxima de CAMINHADA em metros (ex: 500): 200
#
# Buscando coordenadas...
# ✅ Origem  : Midway Mall, Natal, Brazil
#    → nó OSM: 501969167  (lat=-5.81212, lon=-35.20572)
# ✅ Destino : praia shopping, Natal, brazil
#    → nó OSM: 503307654  (lat=-5.86640, lon=-35.18556)
# ✅ Raio máx de caminhada: 200 m

# %%
import osmnx as ox
import folium

# ============================================================
# FUNÇÃO PRINCIPAL DO RIDESMART
# ============================================================

def selecionar_melhor_embarque(G_osm, grafo_carro, grafo_dist_dict,
                                origem_A, destino_B, dist_max_caminhada,
                                algoritmo_busca, coordenadas,
                                otimizar_por='tempo'):
    """
    Encontra o melhor ponto de embarque P dentro do raio de caminhada.

    Parâmetros
    ----------
    G_osm            : grafo OSMnx original (para BFS de vizinhança)
    grafo_carro      : grafo dict{no: dict{vizinho: peso}} com pesos de carro
                       (distância OU tempo, dependendo de otimizar_por)
    grafo_dist_dict  : grafo dict{no: dict{vizinho: distancia}} para medir
                       a caminhada real em metros
    origem_A         : nó de origem
    destino_B        : nó de destino
    dist_max_caminhada: raio máximo de caminhada em metros
    algoritmo_busca  : função (grafo, origem, destino, **kw) -> (caminho, custo, nos_exp)
                       Aceita dijkstra_simples, dijkstra_heap ou a_estrela.
    coordenadas      : dict{no: (lat, lon)} — usado pelo A*
    otimizar_por     : 'tempo' ou 'distancia'

    Retorna
    -------
    melhor_P, dist_caminhada, custo_carro, caminho_carro, nos_expandidos_medio
    """
    # Candidatos a ponto de embarque: nós dentro do raio por BFS de distância
    candidatos = ox.distance.nearest_nodes(
        G_osm,
        X=[G_osm.nodes[no]['x'] for no in G_osm.nodes()],
        Y=[G_osm.nodes[no]['y'] for no in G_osm.nodes()]
    ) if False else None   # placeholder — usamos a abordagem abaixo

    # Coleta todos os nós cuja distância geodésica de A é <= raio
    # (ox.distance.nearest_nodes não serve aqui; usamos ego_graph)
    subgrafo = nx.ego_graph(G_osm, origem_A, radius=dist_max_caminhada, distance='length')
    candidatos = list(subgrafo.nodes())

    melhor_P          = None
    melhor_custo      = float('inf')
    melhor_caminho    = None
    melhor_dist_cam   = 0
    total_nos_exp     = 0
    buscas_realizadas = 0

    for P in candidatos:
        if P == destino_B:
            continue

        # Distância real de caminhada A → P (metros)
        try:
            dist_cam = nx.shortest_path_length(G_osm, origem_A, P, weight='length')
        except nx.NetworkXNoPath:
            continue

        if dist_cam > dist_max_caminhada:
            continue

        # Rota de carro P → B com o algoritmo escolhido
        if algoritmo_busca == a_estrela:
            resultado = algoritmo_busca(grafo_carro, P, destino_B, coordenadas=coordenadas)
        else:
            resultado = algoritmo_busca(grafo_carro, P, destino_B)

        caminho_carro, custo_carro, nos_exp = resultado
        buscas_realizadas += 1
        total_nos_exp += nos_exp

        if caminho_carro is None:
            continue

        if custo_carro < melhor_custo:
            melhor_custo    = custo_carro
            melhor_P        = P
            melhor_caminho  = caminho_carro
            melhor_dist_cam = dist_cam

    nos_exp_medio = total_nos_exp // buscas_realizadas if buscas_realizadas > 0 else 0
    return melhor_P, melhor_dist_cam, melhor_custo, melhor_caminho, nos_exp_medio


def plotar_mapa_ridesmart(G_osm, coord_A, no_P, caminho_carro,
                           coord_B, dist_cam, custo, nome_algoritmo,
                           otimizar_por='tempo'):
    """Plota o mapa do RideSmart com a rota multimodal."""
    coord_P = (G_osm.nodes[no_P]['y'], G_osm.nodes[no_P]['x'])
    coords_carro = [(G_osm.nodes[no]['y'], G_osm.nodes[no]['x']) for no in caminho_carro]

    mapa = folium.Map(location=[coord_A[0], coord_A[1]], zoom_start=14, tiles='cartodbpositron')

    if otimizar_por == 'tempo':
        custo_str = f"{custo/60:.1f} min de carro"
        cor_rota  = 'red'
        icone_cor = 'red'
    else:
        custo_str = f"{custo/1000:.2f} km de carro"
        cor_rota  = 'blue'
        icone_cor = 'blue'

    folium.Marker(
        [coord_A[0], coord_A[1]],
        tooltip="Origem (A)",
        popup=f"<b>Origem</b><br>Caminhe {dist_cam:.0f} m até o ponto verde.",
        icon=folium.Icon(color="darkblue", icon="home", prefix="fa")
    ).add_to(mapa)

    folium.Marker(
        coord_P,
        tooltip="Embarque (P)",
        popup=f"<b>Ponto de Embarque</b><br>{nome_algoritmo}<br>{custo_str}",
        icon=folium.Icon(color="green", icon="car", prefix="fa")
    ).add_to(mapa)

    folium.Marker(
        coords_carro[-1],
        tooltip="Destino (B)",
        popup="<b>Destino Final</b>",
        icon=folium.Icon(color=icone_cor, icon="flag", prefix="fa")
    ).add_to(mapa)

    # Trecho a pé: linha tracejada preta
    folium.PolyLine(
        locations=[[coord_A[0], coord_A[1]], coord_P],
        color='black', weight=3, opacity=0.7, dash_array='6 6',
        tooltip=f"Caminhada: {dist_cam:.0f} m"
    ).add_to(mapa)

    # Trecho de carro
    folium.PolyLine(
        locations=coords_carro,
        color=cor_rota, weight=5, opacity=0.85,
        tooltip=f"Carro ({nome_algoritmo}): {custo_str}"
    ).add_to(mapa)

    return mapa

print("✅ Funções selecionar_melhor_embarque e plotar_mapa_ridesmart definidas.")
# Out:
# ✅ Funções selecionar_melhor_embarque e plotar_mapa_ridesmart definidas.

# %% [markdown]
# ## RideSmart — Dijkstra Simples

# %%
# ============================================================
# RIDESMART — DIJKSTRA SIMPLES
# ============================================================

NOME_ALGORITMO = "Dijkstra Simples"

print("=" * 60)
print(f"  🔍 {NOME_ALGORITMO}")
print(f"  Origem : {endereco_origem}")
print(f"  Destino: {endereco_destino}")
print(f"  Raio   : {raio_caminhada:.0f} m")
print("=" * 60)

# ── 1. MELHOR ROTA POR DISTÂNCIA ──────────────────────────────
print("\n[Distância] Buscando melhor ponto de embarque...")
P_d, cam_d, custo_d, rota_d, nexp_d = selecionar_melhor_embarque(
    G_osm            = G_osm,
    grafo_carro      = grafo_dist,
    grafo_dist_dict  = grafo_dist,
    origem_A         = no_A,
    destino_B        = no_B,
    dist_max_caminhada = raio_caminhada,
    algoritmo_busca  = dijkstra_simples,
    coordenadas      = coordenadas,
    otimizar_por     = 'distancia'
)

if P_d and rota_d:
    print(f"  ✅ Melhor embarque : nó {P_d}")
    print(f"     Caminhada       : {cam_d:.0f} m")
    print(f"     Distância carro : {custo_d/1000:.2f} km")
    print(f"     Nós expandidos  : {nexp_d}")
    mapa_dist = plotar_mapa_ridesmart(
        G_osm, coord_A, P_d, rota_d, coord_B,
        cam_d, custo_d, f"{NOME_ALGORITMO} — Distância", otimizar_por='distancia'
    )
    print("\n📍 Mapa — Melhor rota por DISTÂNCIA:")
    display(mapa_dist)
else:
    print("  ⚠️  Nenhum ponto de embarque válido encontrado.")

# ── 2. MELHOR ROTA POR TEMPO (TRÂNSITO SINTÉTICO) ─────────────
print("\n[Tempo + Trânsito Sintético] Buscando melhor ponto de embarque...")
P_t, cam_t, custo_t, rota_t, nexp_t = selecionar_melhor_embarque(
    G_osm            = G_osm,
    grafo_carro      = grafo_tempo,
    grafo_dist_dict  = grafo_dist,
    origem_A         = no_A,
    destino_B        = no_B,
    dist_max_caminhada = raio_caminhada,
    algoritmo_busca  = dijkstra_simples,
    coordenadas      = coordenadas,
    otimizar_por     = 'tempo'
)

if P_t and rota_t:
    print(f"  ✅ Melhor embarque : nó {P_t}")
    print(f"     Caminhada       : {cam_t:.0f} m")
    print(f"     Tempo carro     : {custo_t/60:.1f} min (com trânsito sintético)")
    print(f"     Nós expandidos  : {nexp_t}")
    mapa_tempo = plotar_mapa_ridesmart(
        G_osm, coord_A, P_t, rota_t, coord_B,
        cam_t, custo_t, f"{NOME_ALGORITMO} — Tempo", otimizar_por='tempo'
    )
    print("\n📍 Mapa — Melhor rota por TEMPO (trânsito sintético):")
    display(mapa_tempo)
else:
    print("  ⚠️  Nenhum ponto de embarque válido encontrado.")


# ── 3. MELHOR ROTA POR TEMPO (SEM TRÂNSITO) ─────────────
print("\n[Tempo Livre] Buscando melhor ponto de embarque (Sem trânsito)...")
P_tl, cam_tl, custo_tl, rota_tl, nexp_tl = selecionar_melhor_embarque(
    G_osm            = G_osm,
    grafo_carro      = grafo_tempo_livre,
    grafo_dist_dict  = grafo_dist,
    origem_A         = no_A,
    destino_B        = no_B,
    dist_max_caminhada = raio_caminhada,
    algoritmo_busca  = dijkstra_simples,
    coordenadas      = coordenadas,
    otimizar_por     = 'tempo'
)

if P_tl and rota_tl:
    print(f"  ✅ Melhor embarque : nó {P_tl}")
    print(f"     Caminhada       : {cam_tl:.0f} m")
    print(f"     Tempo carro     : {custo_tl/60:.1f} min (SEM trânsito)")
    print(f"     Nós expandidos  : {nexp_tl}")
    mapa_tempo_livre = plotar_mapa_ridesmart(
        G_osm, coord_A, P_tl, rota_tl, coord_B,
        cam_tl, custo_tl, f"{NOME_ALGORITMO} — Tempo Livre", otimizar_por='tempo'
    )
    print("\n📍 Mapa — Melhor rota por TEMPO (Sem trânsito):")
    display(mapa_tempo_livre)
# Out:
# ============================================================
#   🔍 Dijkstra Simples
#   Origem : Midway Mall, Natal, Brazil
#   Destino: praia shopping, Natal, brazil
#   Raio   : 200 m
# ============================================================
#
# [Distância] Buscando melhor ponto de embarque...
#   ✅ Melhor embarque : nó 505552907
#      Caminhada       : 159 m
#      Distância carro : 7.24 km
#      Nós expandidos  : 8355
#
# 📍 Mapa — Melhor rota por DISTÂNCIA:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_508381c0e4f58399d2859c6fe3614486 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_508381c0e4f58399d2859c6fe3614486&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_508381c0e4f58399d2859c6fe3614486 = L.map(
#                 &quot;map_508381c0e4f58399d2859c6fe3614486&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_475424207d895c5bc4b77be684976657 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_475424207d895c5bc4b77be684976657.addTo(map_508381c0e4f58399d2859c6fe3614486);
#
#
#             var marker_b749120c3314c42c846cd925b3132e53 = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_508381c0e4f58399d2859c6fe3614486);
#
#
#             var icon_fb1ab09ed3374bf671911ee7821a22e5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a03e720943a11331d77a2a630d25cb3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19cfd0d2dd3214f3321c43a83e2a062a = $(`&lt;div id=&quot;html_19cfd0d2dd3214f3321c43a83e2a062a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 159 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_a03e720943a11331d77a2a630d25cb3d.setContent(html_19cfd0d2dd3214f3321c43a83e2a062a);
#
#
#
#         marker_b749120c3314c42c846cd925b3132e53.bindPopup(popup_a03e720943a11331d77a2a630d25cb3d)
#         ;
#
#
#
#
#             marker_b749120c3314c42c846cd925b3132e53.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_b749120c3314c42c846cd925b3132e53.setIcon(icon_fb1ab09ed3374bf671911ee7821a22e5);
#
#
#             var marker_2cb6947387f5ed4ad5719d6dcec3989b = L.marker(
#                 [-5.8140402, -35.2056243],
#                 {
# }
#             ).addTo(map_508381c0e4f58399d2859c6fe3614486);
#
#
#             var icon_4d47eab56d15e4f20dd09d32ded12142 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_68b28014badcef258b2433a365302bb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f8504b7fb67d1a16144fddf3664886c = $(`&lt;div id=&quot;html_3f8504b7fb67d1a16144fddf3664886c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;Dijkstra Simples — Distância&lt;br&gt;7.24 km de carro&lt;/div&gt;`)[0];
#                 popup_68b28014badcef258b2433a365302bb4.setContent(html_3f8504b7fb67d1a16144fddf3664886c);
#
#
#
#         marker_2cb6947387f5ed4ad5719d6dcec3989b.bindPopup(popup_68b28014badcef258b2433a365302bb4)
#         ;
#
#
#
#
#             marker_2cb6947387f5ed4ad5719d6dcec3989b.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_2cb6947387f5ed4ad5719d6dcec3989b.setIcon(icon_4d47eab56d15e4f20dd09d32ded12142);
#
#
#             var marker_1eff8bdc5627a431efe094ac429d2a32 = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_508381c0e4f58399d2859c6fe3614486);
#
#
#             var icon_793afbb0583e86caa72af3eef79ac2a4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e33006ac5cb65cbecd0f4d0253ec7002 = L.pop
# [Tempo + Trânsito Sintético] Buscando melhor ponto de embarque...
#   ✅ Melhor embarque : nó 505552907
#      Caminhada       : 159 m
#      Tempo carro     : 33.9 min (com trânsito sintético)
#      Nós expandidos  : 7591
#
# 📍 Mapa — Melhor rota por TEMPO (trânsito sintético):
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca2b1e66ba14db7ff4dfa46b41f8de08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca2b1e66ba14db7ff4dfa46b41f8de08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca2b1e66ba14db7ff4dfa46b41f8de08 = L.map(
#                 &quot;map_ca2b1e66ba14db7ff4dfa46b41f8de08&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70384c612f3c8a89490eb8f5a6216e35 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70384c612f3c8a89490eb8f5a6216e35.addTo(map_ca2b1e66ba14db7ff4dfa46b41f8de08);
#
#
#             var marker_009cb299f4c2890d79a22d9a2b7c47d4 = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_ca2b1e66ba14db7ff4dfa46b41f8de08);
#
#
#             var icon_85d549e88fd5e9863a6601dea669fccd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_768b91bfcb5bed8f2bbfe64937e3effe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9c38951c31ad8f288f2d41c4fb525d9 = $(`&lt;div id=&quot;html_b9c38951c31ad8f288f2d41c4fb525d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 159 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_768b91bfcb5bed8f2bbfe64937e3effe.setContent(html_b9c38951c31ad8f288f2d41c4fb525d9);
#
#
#
#         marker_009cb299f4c2890d79a22d9a2b7c47d4.bindPopup(popup_768b91bfcb5bed8f2bbfe64937e3effe)
#         ;
#
#
#
#
#             marker_009cb299f4c2890d79a22d9a2b7c47d4.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_009cb299f4c2890d79a22d9a2b7c47d4.setIcon(icon_85d549e88fd5e9863a6601dea669fccd);
#
#
#             var marker_14935b70559c374197a1e588adb9fc62 = L.marker(
#                 [-5.8140402, -35.2056243],
#                 {
# }
#             ).addTo(map_ca2b1e66ba14db7ff4dfa46b41f8de08);
#
#
#             var icon_c8aeae3418787578390e8d57e1d8cab3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cab74cbecf83edcfb661b8fe98d11f8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a6fee7481ae8404212270dadcb1ab93 = $(`&lt;div id=&quot;html_7a6fee7481ae8404212270dadcb1ab93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;Dijkstra Simples — Tempo&lt;br&gt;33.9 min de carro&lt;/div&gt;`)[0];
#                 popup_cab74cbecf83edcfb661b8fe98d11f8d.setContent(html_7a6fee7481ae8404212270dadcb1ab93);
#
#
#
#         marker_14935b70559c374197a1e588adb9fc62.bindPopup(popup_cab74cbecf83edcfb661b8fe98d11f8d)
#         ;
#
#
#
#
#             marker_14935b70559c374197a1e588adb9fc62.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_14935b70559c374197a1e588adb9fc62.setIcon(icon_c8aeae3418787578390e8d57e1d8cab3);
#
#
#             var marker_dfb41c7dae7efd8ee20b3fa52996fed8 = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_ca2b1e66ba14db7ff4dfa46b41f8de08);
#
#
#             var icon_a06a49073e0e1fb38a0a9025511ca8d8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1d210d71c72f95d4b30166acde2e5f56 = L.popup({
# [Tempo Livre] Buscando melhor ponto de embarque (Sem trânsito)...
#   ✅ Melhor embarque : nó 505552907
#      Caminhada       : 159 m
#      Tempo carro     : 6.5 min (SEM trânsito)
#      Nós expandidos  : 7228
#
# 📍 Mapa — Melhor rota por TEMPO (Sem trânsito):
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_443eb9734936a3692b8bb88e47808434 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_443eb9734936a3692b8bb88e47808434&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_443eb9734936a3692b8bb88e47808434 = L.map(
#                 &quot;map_443eb9734936a3692b8bb88e47808434&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53ebb6a198b4e8adefefcb5e33dc405f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53ebb6a198b4e8adefefcb5e33dc405f.addTo(map_443eb9734936a3692b8bb88e47808434);
#
#
#             var marker_29116c958572ecbd953966a28e5f8647 = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_443eb9734936a3692b8bb88e47808434);
#
#
#             var icon_6b6bbf335f7fffe06c23b12c076e92f5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f7f428a2cd0ba94f064607feba2d774f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2db91dfad433d946d37087fb0eaefa4b = $(`&lt;div id=&quot;html_2db91dfad433d946d37087fb0eaefa4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 159 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_f7f428a2cd0ba94f064607feba2d774f.setContent(html_2db91dfad433d946d37087fb0eaefa4b);
#
#
#
#         marker_29116c958572ecbd953966a28e5f8647.bindPopup(popup_f7f428a2cd0ba94f064607feba2d774f)
#         ;
#
#
#
#
#             marker_29116c958572ecbd953966a28e5f8647.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_29116c958572ecbd953966a28e5f8647.setIcon(icon_6b6bbf335f7fffe06c23b12c076e92f5);
#
#
#             var marker_6e4d8b22bde7b947afb941dc2455fd55 = L.marker(
#                 [-5.8140402, -35.2056243],
#                 {
# }
#             ).addTo(map_443eb9734936a3692b8bb88e47808434);
#
#
#             var icon_973852b44493cae453b1ed6b31c300bd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a11a0b4af87e4e305cee64f0a8c5e714 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb4bda98316d5279baf8d34d620fede3 = $(`&lt;div id=&quot;html_cb4bda98316d5279baf8d34d620fede3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;Dijkstra Simples — Tempo Livre&lt;br&gt;6.5 min de carro&lt;/div&gt;`)[0];
#                 popup_a11a0b4af87e4e305cee64f0a8c5e714.setContent(html_cb4bda98316d5279baf8d34d620fede3);
#
#
#
#         marker_6e4d8b22bde7b947afb941dc2455fd55.bindPopup(popup_a11a0b4af87e4e305cee64f0a8c5e714)
#         ;
#
#
#
#
#             marker_6e4d8b22bde7b947afb941dc2455fd55.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_6e4d8b22bde7b947afb941dc2455fd55.setIcon(icon_973852b44493cae453b1ed6b31c300bd);
#
#
#             var marker_35b97ad6cb3d6b95696498b3069f6a65 = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_443eb9734936a3692b8bb88e47808434);
#
#
#             var icon_f6e228efe27893fb980517b4e3a53810 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_70fc363b93417920fa9acc46d98752ec = L.po

# %% [markdown]
# ## RideSmart — Dijkstra com Heap

# %%
# ============================================================
# RIDESMART — DIJKSTRA COM HEAP
# ============================================================

NOME_ALGORITMO = "Dijkstra com Heap"

print("=" * 60)
print(f"  🔍 {NOME_ALGORITMO}")
print(f"  Origem : {endereco_origem}")
print(f"  Destino: {endereco_destino}")
print(f"  Raio   : {raio_caminhada:.0f} m")
print("=" * 60)

# ── 1. MELHOR ROTA POR DISTÂNCIA ──────────────────────────────
print("\n[Distância] Buscando melhor ponto de embarque...")
P_d, cam_d, custo_d, rota_d, nexp_d = selecionar_melhor_embarque(
    G_osm            = G_osm,
    grafo_carro      = grafo_dist,
    grafo_dist_dict  = grafo_dist,
    origem_A         = no_A,
    destino_B        = no_B,
    dist_max_caminhada = raio_caminhada,
    algoritmo_busca  = dijkstra_heap,
    coordenadas      = coordenadas,
    otimizar_por     = 'distancia'
)

if P_d and rota_d:
    print(f"  ✅ Melhor embarque : nó {P_d}")
    print(f"     Caminhada       : {cam_d:.0f} m")
    print(f"     Distância carro : {custo_d/1000:.2f} km")
    print(f"     Nós expandidos  : {nexp_d}")
    mapa_dist = plotar_mapa_ridesmart(
        G_osm, coord_A, P_d, rota_d, coord_B,
        cam_d, custo_d, f"{NOME_ALGORITMO} — Distância", otimizar_por='distancia'
    )
    print("\n📍 Mapa — Melhor rota por DISTÂNCIA:")
    display(mapa_dist)
else:
    print("  ⚠️  Nenhum ponto de embarque válido encontrado.")

# ── 2. MELHOR ROTA POR TEMPO (TRÂNSITO SINTÉTICO) ─────────────
print("\n[Tempo + Trânsito Sintético] Buscando melhor ponto de embarque...")
P_t, cam_t, custo_t, rota_t, nexp_t = selecionar_melhor_embarque(
    G_osm            = G_osm,
    grafo_carro      = grafo_tempo,
    grafo_dist_dict  = grafo_dist,
    origem_A         = no_A,
    destino_B        = no_B,
    dist_max_caminhada = raio_caminhada,
    algoritmo_busca  = dijkstra_heap,
    coordenadas      = coordenadas,
    otimizar_por     = 'tempo'
)

if P_t and rota_t:
    print(f"  ✅ Melhor embarque : nó {P_t}")
    print(f"     Caminhada       : {cam_t:.0f} m")
    print(f"     Tempo carro     : {custo_t/60:.1f} min (com trânsito sintético)")
    print(f"     Nós expandidos  : {nexp_t}")
    mapa_tempo = plotar_mapa_ridesmart(
        G_osm, coord_A, P_t, rota_t, coord_B,
        cam_t, custo_t, f"{NOME_ALGORITMO} — Tempo", otimizar_por='tempo'
    )
    print("\n📍 Mapa — Melhor rota por TEMPO (trânsito sintético):")
    display(mapa_tempo)
else:
    print("  ⚠️  Nenhum ponto de embarque válido encontrado.")
# Out:
# ============================================================
#   🔍 Dijkstra com Heap
#   Origem : Midway Mall, Natal, Brazil
#   Destino: praia shopping, Natal, brazil
#   Raio   : 200 m
# ============================================================
#
# [Distância] Buscando melhor ponto de embarque...
#   ✅ Melhor embarque : nó 505552907
#      Caminhada       : 159 m
#      Distância carro : 7.24 km
#      Nós expandidos  : 8356
#
# 📍 Mapa — Melhor rota por DISTÂNCIA:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d192cd46496e6583ab888d51ef9ca0b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d192cd46496e6583ab888d51ef9ca0b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d192cd46496e6583ab888d51ef9ca0b6 = L.map(
#                 &quot;map_d192cd46496e6583ab888d51ef9ca0b6&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f43b5f9c51f4bab9a961d230bb1a511d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f43b5f9c51f4bab9a961d230bb1a511d.addTo(map_d192cd46496e6583ab888d51ef9ca0b6);
#
#
#             var marker_8e6c9c4081e2c444d351d53a3f2b31ee = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_d192cd46496e6583ab888d51ef9ca0b6);
#
#
#             var icon_f5e0590053bef76952709ef202c65e39 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e15aeb04f81a81d5601704ce0d98f03a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9787c7c19f7d264264c6c78bd92c29d = $(`&lt;div id=&quot;html_c9787c7c19f7d264264c6c78bd92c29d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 159 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_e15aeb04f81a81d5601704ce0d98f03a.setContent(html_c9787c7c19f7d264264c6c78bd92c29d);
#
#
#
#         marker_8e6c9c4081e2c444d351d53a3f2b31ee.bindPopup(popup_e15aeb04f81a81d5601704ce0d98f03a)
#         ;
#
#
#
#
#             marker_8e6c9c4081e2c444d351d53a3f2b31ee.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_8e6c9c4081e2c444d351d53a3f2b31ee.setIcon(icon_f5e0590053bef76952709ef202c65e39);
#
#
#             var marker_465c3c37f2c18001a48cee497f319ef2 = L.marker(
#                 [-5.8140402, -35.2056243],
#                 {
# }
#             ).addTo(map_d192cd46496e6583ab888d51ef9ca0b6);
#
#
#             var icon_0d7594367669c1449a08c4856aea4e76 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_49d180ad6cb4f582e18c863fcabf662e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_866538b32934eba5ba1c8ad21a5aa51a = $(`&lt;div id=&quot;html_866538b32934eba5ba1c8ad21a5aa51a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;Dijkstra com Heap — Distância&lt;br&gt;7.24 km de carro&lt;/div&gt;`)[0];
#                 popup_49d180ad6cb4f582e18c863fcabf662e.setContent(html_866538b32934eba5ba1c8ad21a5aa51a);
#
#
#
#         marker_465c3c37f2c18001a48cee497f319ef2.bindPopup(popup_49d180ad6cb4f582e18c863fcabf662e)
#         ;
#
#
#
#
#             marker_465c3c37f2c18001a48cee497f319ef2.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_465c3c37f2c18001a48cee497f319ef2.setIcon(icon_0d7594367669c1449a08c4856aea4e76);
#
#
#             var marker_eb6f09311db69fcd2b7894a5711afb8c = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_d192cd46496e6583ab888d51ef9ca0b6);
#
#
#             var icon_46fe0e7efb9813ff85763fe3a1c00844 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c18c92e6ce682ff3ef40153b383d9f04 = L.po
# [Tempo + Trânsito Sintético] Buscando melhor ponto de embarque...
#   ✅ Melhor embarque : nó 505552907
#      Caminhada       : 159 m
#      Tempo carro     : 33.9 min (com trânsito sintético)
#      Nós expandidos  : 7592
#
# 📍 Mapa — Melhor rota por TEMPO (trânsito sintético):
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d69bdcf907f48d2831c919a525704327 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d69bdcf907f48d2831c919a525704327&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d69bdcf907f48d2831c919a525704327 = L.map(
#                 &quot;map_d69bdcf907f48d2831c919a525704327&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14ab5497285719f58757d5273f0abec7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_14ab5497285719f58757d5273f0abec7.addTo(map_d69bdcf907f48d2831c919a525704327);
#
#
#             var marker_1c71e509e20696c3d301611a0b49e5e6 = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_d69bdcf907f48d2831c919a525704327);
#
#
#             var icon_94144292134d2d1fea40b27504db5942 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_eb0c01e7c1f0810bdbf50f4dc1c6bf7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74919703d95fe8f80bd7cf4fe4f78222 = $(`&lt;div id=&quot;html_74919703d95fe8f80bd7cf4fe4f78222&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 159 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_eb0c01e7c1f0810bdbf50f4dc1c6bf7e.setContent(html_74919703d95fe8f80bd7cf4fe4f78222);
#
#
#
#         marker_1c71e509e20696c3d301611a0b49e5e6.bindPopup(popup_eb0c01e7c1f0810bdbf50f4dc1c6bf7e)
#         ;
#
#
#
#
#             marker_1c71e509e20696c3d301611a0b49e5e6.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_1c71e509e20696c3d301611a0b49e5e6.setIcon(icon_94144292134d2d1fea40b27504db5942);
#
#
#             var marker_60972bf725b2ef4575ece9c0e2f1a715 = L.marker(
#                 [-5.8140402, -35.2056243],
#                 {
# }
#             ).addTo(map_d69bdcf907f48d2831c919a525704327);
#
#
#             var icon_eab3d214ae47b38eb8e9106d393ad1e6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_19252459f201b9346ec83719de3d8c88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e590c664b34701a904a3c68ab7f8de65 = $(`&lt;div id=&quot;html_e590c664b34701a904a3c68ab7f8de65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;Dijkstra com Heap — Tempo&lt;br&gt;33.9 min de carro&lt;/div&gt;`)[0];
#                 popup_19252459f201b9346ec83719de3d8c88.setContent(html_e590c664b34701a904a3c68ab7f8de65);
#
#
#
#         marker_60972bf725b2ef4575ece9c0e2f1a715.bindPopup(popup_19252459f201b9346ec83719de3d8c88)
#         ;
#
#
#
#
#             marker_60972bf725b2ef4575ece9c0e2f1a715.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_60972bf725b2ef4575ece9c0e2f1a715.setIcon(icon_eab3d214ae47b38eb8e9106d393ad1e6);
#
#
#             var marker_e851d43af057b81b386ef444900e1b52 = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_d69bdcf907f48d2831c919a525704327);
#
#
#             var icon_e8654c5945441e96290d92e363c6650c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a3a02198e45d4943aac0e21f79662d02 = L.popup(

# %% [markdown]
# ## RideSmart — A*

# %%
# ============================================================
# RIDESMART — A*
# ============================================================

NOME_ALGORITMO = "A*"

print("=" * 60)
print(f"  🔍 {NOME_ALGORITMO}")
print(f"  Origem : {endereco_origem}")
print(f"  Destino: {endereco_destino}")
print(f"  Raio   : {raio_caminhada:.0f} m")
print("=" * 60)

# ── 1. MELHOR ROTA POR DISTÂNCIA ──────────────────────────────
print("\n[Distância] Buscando melhor ponto de embarque...")
P_d, cam_d, custo_d, rota_d, nexp_d = selecionar_melhor_embarque(
    G_osm            = G_osm,
    grafo_carro      = grafo_dist,
    grafo_dist_dict  = grafo_dist,
    origem_A         = no_A,
    destino_B        = no_B,
    dist_max_caminhada = raio_caminhada,
    algoritmo_busca  = a_estrela,
    coordenadas      = coordenadas,
    otimizar_por     = 'distancia'
)

if P_d and rota_d:
    print(f"  ✅ Melhor embarque : nó {P_d}")
    print(f"     Caminhada       : {cam_d:.0f} m")
    print(f"     Distância carro : {custo_d/1000:.2f} km")
    print(f"     Nós expandidos  : {nexp_d}")
    mapa_dist = plotar_mapa_ridesmart(
        G_osm, coord_A, P_d, rota_d, coord_B,
        cam_d, custo_d, f"{NOME_ALGORITMO} — Distância", otimizar_por='distancia'
    )
    print("\n📍 Mapa — Melhor rota por DISTÂNCIA:")
    display(mapa_dist)
else:
    print("  ⚠️  Nenhum ponto de embarque válido encontrado.")

# ── 2. MELHOR ROTA POR TEMPO (TRÂNSITO SINTÉTICO) ─────────────
print("\n[Tempo + Trânsito Sintético] Buscando melhor ponto de embarque...")
P_t, cam_t, custo_t, rota_t, nexp_t = selecionar_melhor_embarque(
    G_osm            = G_osm,
    grafo_carro      = grafo_tempo,
    grafo_dist_dict  = grafo_dist,
    origem_A         = no_A,
    destino_B        = no_B,
    dist_max_caminhada = raio_caminhada,
    algoritmo_busca  = a_estrela,
    coordenadas      = coordenadas,
    otimizar_por     = 'tempo'
)

if P_t and rota_t:
    print(f"  ✅ Melhor embarque : nó {P_t}")
    print(f"     Caminhada       : {cam_t:.0f} m")
    print(f"     Tempo carro     : {custo_t/60:.1f} min (com trânsito sintético)")
    print(f"     Nós expandidos  : {nexp_t}")
    mapa_tempo = plotar_mapa_ridesmart(
        G_osm, coord_A, P_t, rota_t, coord_B,
        cam_t, custo_t, f"{NOME_ALGORITMO} — Tempo", otimizar_por='tempo'
    )
    print("\n📍 Mapa — Melhor rota por TEMPO (trânsito sintético):")
    display(mapa_tempo)
else:
    print("  ⚠️  Nenhum ponto de embarque válido encontrado.")
# ── 3. MELHOR ROTA POR TEMPO (SEM TRÂNSITO) ─────────────
print("\n[Tempo Livre] Buscando melhor ponto de embarque (Sem trânsito)...")
P_tl, cam_tl, custo_tl, rota_tl, nexp_tl = selecionar_melhor_embarque(
    G_osm            = G_osm,
    grafo_carro      = grafo_tempo_livre,
    grafo_dist_dict  = grafo_dist,
    origem_A         = no_A,
    destino_B        = no_B,
    dist_max_caminhada = raio_caminhada,
    algoritmo_busca  = a_estrela,
    coordenadas      = coordenadas,
    otimizar_por     = 'tempo'
)

if P_tl and rota_tl:
    print(f"  ✅ Melhor embarque : nó {P_tl}")
    print(f"     Caminhada       : {cam_tl:.0f} m")
    print(f"     Tempo carro     : {custo_tl/60:.1f} min (SEM trânsito)")
    print(f"     Nós expandidos  : {nexp_tl}")
    mapa_tempo_livre = plotar_mapa_ridesmart(
        G_osm, coord_A, P_tl, rota_tl, coord_B,
        cam_tl, custo_tl, f"{NOME_ALGORITMO} — Tempo Livre", otimizar_por='tempo'
    )
    print("\n📍 Mapa — Melhor rota por TEMPO (Sem trânsito):")
    display(mapa_tempo_livre)
# Out:
# ============================================================
#   🔍 A*
#   Origem : Midway Mall, Natal, Brazil
#   Destino: praia shopping, Natal, brazil
#   Raio   : 200 m
# ============================================================
#
# [Distância] Buscando melhor ponto de embarque...
#   ✅ Melhor embarque : nó 505552907
#      Caminhada       : 159 m
#      Distância carro : 7.24 km
#      Nós expandidos  : 7674
#
# 📍 Mapa — Melhor rota por DISTÂNCIA:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fcefc81e781fcf076106210dfbec348 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fcefc81e781fcf076106210dfbec348&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fcefc81e781fcf076106210dfbec348 = L.map(
#                 &quot;map_3fcefc81e781fcf076106210dfbec348&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_826ebd8276adead80f70441cfaab2d8a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_826ebd8276adead80f70441cfaab2d8a.addTo(map_3fcefc81e781fcf076106210dfbec348);
#
#
#             var marker_57b98953cf3273ab143f3b71d98659b6 = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_3fcefc81e781fcf076106210dfbec348);
#
#
#             var icon_67484b7a3876679c0cd6f7e7221e329a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ba4a5e63588cbb71e2c396ed8a1c0eb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a693c2eff1cabda27246b0d366ed42b1 = $(`&lt;div id=&quot;html_a693c2eff1cabda27246b0d366ed42b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 159 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_ba4a5e63588cbb71e2c396ed8a1c0eb3.setContent(html_a693c2eff1cabda27246b0d366ed42b1);
#
#
#
#         marker_57b98953cf3273ab143f3b71d98659b6.bindPopup(popup_ba4a5e63588cbb71e2c396ed8a1c0eb3)
#         ;
#
#
#
#
#             marker_57b98953cf3273ab143f3b71d98659b6.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_57b98953cf3273ab143f3b71d98659b6.setIcon(icon_67484b7a3876679c0cd6f7e7221e329a);
#
#
#             var marker_f0b484ad13d9593bb785a03425699f63 = L.marker(
#                 [-5.8140402, -35.2056243],
#                 {
# }
#             ).addTo(map_3fcefc81e781fcf076106210dfbec348);
#
#
#             var icon_1b3fa374dc7318f41724775b6d253d0b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1ad9a20bdec97c29ef1d90cd478e85b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4814838e250843878d38c7089b5f35c = $(`&lt;div id=&quot;html_a4814838e250843878d38c7089b5f35c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;A* — Distância&lt;br&gt;7.24 km de carro&lt;/div&gt;`)[0];
#                 popup_1ad9a20bdec97c29ef1d90cd478e85b7.setContent(html_a4814838e250843878d38c7089b5f35c);
#
#
#
#         marker_f0b484ad13d9593bb785a03425699f63.bindPopup(popup_1ad9a20bdec97c29ef1d90cd478e85b7)
#         ;
#
#
#
#
#             marker_f0b484ad13d9593bb785a03425699f63.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f0b484ad13d9593bb785a03425699f63.setIcon(icon_1b3fa374dc7318f41724775b6d253d0b);
#
#
#             var marker_47111ead857cb92a6ee5040351784992 = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_3fcefc81e781fcf076106210dfbec348);
#
#
#             var icon_8fddd1be98ae4b52c9123d5d510548c8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_18bc0e477a2d06747f36b4c0bb3d8502 = L.popup({
#   &quot;m
# [Tempo + Trânsito Sintético] Buscando melhor ponto de embarque...
#   ✅ Melhor embarque : nó 505552907
#      Caminhada       : 159 m
#      Tempo carro     : 33.9 min (com trânsito sintético)
#      Nós expandidos  : 5107
#
# 📍 Mapa — Melhor rota por TEMPO (trânsito sintético):
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdc7c901d36e89343149567b5a39512e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdc7c901d36e89343149567b5a39512e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdc7c901d36e89343149567b5a39512e = L.map(
#                 &quot;map_fdc7c901d36e89343149567b5a39512e&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f177242f9d7a5fbec2eed182bf7238f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f177242f9d7a5fbec2eed182bf7238f.addTo(map_fdc7c901d36e89343149567b5a39512e);
#
#
#             var marker_1cf8aeb0caaff0ae8e9bc3e590580b19 = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_fdc7c901d36e89343149567b5a39512e);
#
#
#             var icon_700628bbc042198edf87d54d52c645d5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_630421ff92699223ed1fe5daf110bbdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0faa899addd22ab7f4cb7b13ca934bc8 = $(`&lt;div id=&quot;html_0faa899addd22ab7f4cb7b13ca934bc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 159 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_630421ff92699223ed1fe5daf110bbdc.setContent(html_0faa899addd22ab7f4cb7b13ca934bc8);
#
#
#
#         marker_1cf8aeb0caaff0ae8e9bc3e590580b19.bindPopup(popup_630421ff92699223ed1fe5daf110bbdc)
#         ;
#
#
#
#
#             marker_1cf8aeb0caaff0ae8e9bc3e590580b19.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_1cf8aeb0caaff0ae8e9bc3e590580b19.setIcon(icon_700628bbc042198edf87d54d52c645d5);
#
#
#             var marker_eb561b22bf33f8c084d4055447a4c9cf = L.marker(
#                 [-5.8140402, -35.2056243],
#                 {
# }
#             ).addTo(map_fdc7c901d36e89343149567b5a39512e);
#
#
#             var icon_bb53ef51f38da18f0a71383a09d89580 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d6834aa61bafc12dff8d40d0f6753bc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc779ba87fcfe0a98f8b5cdabe88fc98 = $(`&lt;div id=&quot;html_dc779ba87fcfe0a98f8b5cdabe88fc98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;A* — Tempo&lt;br&gt;33.9 min de carro&lt;/div&gt;`)[0];
#                 popup_d6834aa61bafc12dff8d40d0f6753bc2.setContent(html_dc779ba87fcfe0a98f8b5cdabe88fc98);
#
#
#
#         marker_eb561b22bf33f8c084d4055447a4c9cf.bindPopup(popup_d6834aa61bafc12dff8d40d0f6753bc2)
#         ;
#
#
#
#
#             marker_eb561b22bf33f8c084d4055447a4c9cf.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_eb561b22bf33f8c084d4055447a4c9cf.setIcon(icon_bb53ef51f38da18f0a71383a09d89580);
#
#
#             var marker_a2d5957fb4b0b7172be4400149a295ae = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_fdc7c901d36e89343149567b5a39512e);
#
#
#             var icon_e99d5e38bd8f6132d2147ca7ffafeb2b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_449e49e10a802917f86346c8791ab2a9 = L.popup({
#   &quot;maxWi
# [Tempo Livre] Buscando melhor ponto de embarque (Sem trânsito)...
#   ✅ Melhor embarque : nó 505552907
#      Caminhada       : 159 m
#      Tempo carro     : 6.5 min (SEM trânsito)
#      Nós expandidos  : 7228
#
# 📍 Mapa — Melhor rota por TEMPO (Sem trânsito):
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b844805e83960ec8544111fac03a12b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b844805e83960ec8544111fac03a12b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b844805e83960ec8544111fac03a12b = L.map(
#                 &quot;map_2b844805e83960ec8544111fac03a12b&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75a47d9dbbcac6783145ad7fe3442a82 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75a47d9dbbcac6783145ad7fe3442a82.addTo(map_2b844805e83960ec8544111fac03a12b);
#
#
#             var marker_01dbbb4e16739fec762359a53e8a07c3 = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_2b844805e83960ec8544111fac03a12b);
#
#
#             var icon_82d25bd31c9a85c55eb9f9b73bc10b6e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_83ef1b5d2e0e6bc5e5969f53dba25585 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88582dff94ced88edb4bcc39903c94f5 = $(`&lt;div id=&quot;html_88582dff94ced88edb4bcc39903c94f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 159 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_83ef1b5d2e0e6bc5e5969f53dba25585.setContent(html_88582dff94ced88edb4bcc39903c94f5);
#
#
#
#         marker_01dbbb4e16739fec762359a53e8a07c3.bindPopup(popup_83ef1b5d2e0e6bc5e5969f53dba25585)
#         ;
#
#
#
#
#             marker_01dbbb4e16739fec762359a53e8a07c3.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_01dbbb4e16739fec762359a53e8a07c3.setIcon(icon_82d25bd31c9a85c55eb9f9b73bc10b6e);
#
#
#             var marker_28d35612af24d09da0d73c78712497f0 = L.marker(
#                 [-5.8140402, -35.2056243],
#                 {
# }
#             ).addTo(map_2b844805e83960ec8544111fac03a12b);
#
#
#             var icon_220c5f08e907bf1318bb06e856dbf1db = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a03c70c42ea2213c55a5cbbc3e8e8c3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fc05618c1ccad05aa43c8a1a3a89458 = $(`&lt;div id=&quot;html_4fc05618c1ccad05aa43c8a1a3a89458&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;A* — Tempo Livre&lt;br&gt;6.5 min de carro&lt;/div&gt;`)[0];
#                 popup_a03c70c42ea2213c55a5cbbc3e8e8c3e.setContent(html_4fc05618c1ccad05aa43c8a1a3a89458);
#
#
#
#         marker_28d35612af24d09da0d73c78712497f0.bindPopup(popup_a03c70c42ea2213c55a5cbbc3e8e8c3e)
#         ;
#
#
#
#
#             marker_28d35612af24d09da0d73c78712497f0.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_28d35612af24d09da0d73c78712497f0.setIcon(icon_220c5f08e907bf1318bb06e856dbf1db);
#
#
#             var marker_2a021ed90a139d0622a59eada4b32d5f = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_2b844805e83960ec8544111fac03a12b);
#
#
#             var icon_f35505c166474d56996803945113e005 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8fce449ee53d0a640c071afc3182c1f8 = L.popup({
#   &quot;

# %% [markdown]
# ## RideSmart — Dijkstra Bidirecional

# %%
# ============================================================
# RIDESMART — DIJKSTRA BIDIRECIONAL
# ============================================================

def dijkstra_bidir_wrapper(grafo_lista, origem, destino, **kw):
    """Adapta DijkstraBidirecional à assinatura (grafo, origem, destino) -> (caminho, custo, nos_exp)."""
    grafo_rev = {no: [] for no in grafo_lista}
    for u in grafo_lista:
        for v, w in grafo_lista[u]:
            grafo_rev[v].append((u, w))
    caminho, custo = DijkstraBidirecional(grafo_lista, grafo_rev, origem, destino)
    nos_exp = len(caminho) if caminho else 0
    return caminho, custo, nos_exp

grafo_dist_lst  = {no: list(grafo_dist[no].items())  for no in grafo_dist}
grafo_tempo_lst = {no: list(grafo_tempo[no].items()) for no in grafo_tempo}

NOME_ALGORITMO = "Dijkstra Bidirecional"

print("=" * 60)
print(f"  🔍 {NOME_ALGORITMO}")
print(f"  Origem : {endereco_origem}")
print(f"  Destino: {endereco_destino}")
print(f"  Raio   : {raio_caminhada:.0f} m")
print("=" * 60)

# ── 1. MELHOR ROTA POR DISTÂNCIA ──────────────────────────────
print("\n[Distância] Buscando melhor ponto de embarque...")
P_d, cam_d, custo_d, rota_d, nexp_d = selecionar_melhor_embarque(
    G_osm            = G_osm,
    grafo_carro      = grafo_dist_lst,
    grafo_dist_dict  = grafo_dist,
    origem_A         = no_A,
    destino_B        = no_B,
    dist_max_caminhada = raio_caminhada,
    algoritmo_busca  = dijkstra_bidir_wrapper,
    coordenadas      = coordenadas,
    otimizar_por     = 'distancia'
)

if P_d and rota_d:
    print(f"  ✅ Melhor embarque : nó {P_d}")
    print(f"     Caminhada       : {cam_d:.0f} m")
    print(f"     Distância carro : {custo_d/1000:.2f} km")
    print(f"     Nós expandidos  : {nexp_d}")
    mapa_dist = plotar_mapa_ridesmart(
        G_osm, coord_A, P_d, rota_d, coord_B,
        cam_d, custo_d, f"{NOME_ALGORITMO} — Distância", otimizar_por='distancia'
    )
    print("\n📍 Mapa — Melhor rota por DISTÂNCIA:")
    display(mapa_dist)
else:
    print("  ⚠️  Nenhum ponto de embarque válido encontrado.")

# ── 2. MELHOR ROTA POR TEMPO (TRÂNSITO SINTÉTICO) ─────────────
print("\n[Tempo + Trânsito Sintético] Buscando melhor ponto de embarque...")
P_t, cam_t, custo_t, rota_t, nexp_t = selecionar_melhor_embarque(
    G_osm            = G_osm,
    grafo_carro      = grafo_tempo_lst,
    grafo_dist_dict  = grafo_dist,
    origem_A         = no_A,
    destino_B        = no_B,
    dist_max_caminhada = raio_caminhada,
    algoritmo_busca  = dijkstra_bidir_wrapper,
    coordenadas      = coordenadas,
    otimizar_por     = 'tempo'
)

if P_t and rota_t:
    print(f"  ✅ Melhor embarque : nó {P_t}")
    print(f"     Caminhada       : {cam_t:.0f} m")
    print(f"     Tempo carro     : {custo_t/60:.1f} min (com trânsito sintético)")
    print(f"     Nós expandidos  : {nexp_t}")
    mapa_tempo = plotar_mapa_ridesmart(
        G_osm, coord_A, P_t, rota_t, coord_B,
        cam_t, custo_t, f"{NOME_ALGORITMO} — Tempo", otimizar_por='tempo'
    )
    print("\n📍 Mapa — Melhor rota por TEMPO (trânsito sintético):")
    display(mapa_tempo)
else:
    print("  ⚠️  Nenhum ponto de embarque válido encontrado.")
# ── 3. MELHOR ROTA POR TEMPO (SEM TRÂNSITO) ─────────────
print("\n[Tempo Livre] Buscando melhor ponto de embarque (Sem trânsito)...")
P_tl, cam_tl, custo_tl, rota_tl, nexp_tl = selecionar_melhor_embarque(
    G_osm            = G_osm,
    grafo_carro      = grafo_tempo_livre,
    grafo_dist_dict  = grafo_dist,
    origem_A         = no_A,
    destino_B        = no_B,
    dist_max_caminhada = raio_caminhada,
    algoritmo_busca  = dijkstra_bidir_wrapper,
    coordenadas      = coordenadas,
    otimizar_por     = 'tempo'
)

if P_tl and rota_tl:
    print(f"  ✅ Melhor embarque : nó {P_tl}")
    print(f"     Caminhada       : {cam_tl:.0f} m")
    print(f"     Tempo carro     : {custo_tl/60:.1f} min (SEM trânsito)")
    print(f"     Nós expandidos  : {nexp_tl}")
    mapa_tempo_livre = plotar_mapa_ridesmart(
        G_osm, coord_A, P_tl, rota_tl, coord_B,
        cam_tl, custo_tl, f"{NOME_ALGORITMO} — Tempo Livre", otimizar_por='tempo'
    )
    print("\n📍 Mapa — Melhor rota por TEMPO (Sem trânsito):")
    display(mapa_tempo_livre)
# Out:
# ============================================================
#   🔍 Dijkstra Bidirecional
#   Origem : Midway Mall, Natal, Brazil
#   Destino: praia shopping, Natal, brazil
#   Raio   : 200 m
# ============================================================
#
# [Distância] Buscando melhor ponto de embarque...
#   ✅ Melhor embarque : nó 505552907
#      Caminhada       : 159 m
#      Distância carro : 7.24 km
#      Nós expandidos  : 71
#
# 📍 Mapa — Melhor rota por DISTÂNCIA:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76f7c161e4d5d50a8063582481b2416e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76f7c161e4d5d50a8063582481b2416e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76f7c161e4d5d50a8063582481b2416e = L.map(
#                 &quot;map_76f7c161e4d5d50a8063582481b2416e&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_acceaf57dc170bf8a4747a117ab38485 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_acceaf57dc170bf8a4747a117ab38485.addTo(map_76f7c161e4d5d50a8063582481b2416e);
#
#
#             var marker_2062b079a02d3225754454ff18ee79d9 = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_76f7c161e4d5d50a8063582481b2416e);
#
#
#             var icon_d0dc51f7513b123a601a19b7575ed56b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3c30d641e3b210393e99bc4379998ce7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9dd3f6593f7fbc864672a08f192b06f = $(`&lt;div id=&quot;html_b9dd3f6593f7fbc864672a08f192b06f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 159 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_3c30d641e3b210393e99bc4379998ce7.setContent(html_b9dd3f6593f7fbc864672a08f192b06f);
#
#
#
#         marker_2062b079a02d3225754454ff18ee79d9.bindPopup(popup_3c30d641e3b210393e99bc4379998ce7)
#         ;
#
#
#
#
#             marker_2062b079a02d3225754454ff18ee79d9.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_2062b079a02d3225754454ff18ee79d9.setIcon(icon_d0dc51f7513b123a601a19b7575ed56b);
#
#
#             var marker_0ab2db719114ffa735f2edf2b88bbaeb = L.marker(
#                 [-5.8140402, -35.2056243],
#                 {
# }
#             ).addTo(map_76f7c161e4d5d50a8063582481b2416e);
#
#
#             var icon_c04b7c5ac1c622850a6e7d232cefd2c8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_00fd01e562cb7fd40d04129a071f2a12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfa29c4b1ed62923e05ef34ccc71ff97 = $(`&lt;div id=&quot;html_cfa29c4b1ed62923e05ef34ccc71ff97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;Dijkstra Bidirecional — Distância&lt;br&gt;7.24 km de carro&lt;/div&gt;`)[0];
#                 popup_00fd01e562cb7fd40d04129a071f2a12.setContent(html_cfa29c4b1ed62923e05ef34ccc71ff97);
#
#
#
#         marker_0ab2db719114ffa735f2edf2b88bbaeb.bindPopup(popup_00fd01e562cb7fd40d04129a071f2a12)
#         ;
#
#
#
#
#             marker_0ab2db719114ffa735f2edf2b88bbaeb.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_0ab2db719114ffa735f2edf2b88bbaeb.setIcon(icon_c04b7c5ac1c622850a6e7d232cefd2c8);
#
#
#             var marker_c44a9c01dedc4f84290b1dbb8596fe84 = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_76f7c161e4d5d50a8063582481b2416e);
#
#
#             var icon_d19d439510f6237e6adf85bdf6a3e843 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_90fe841b647de8e5fccc4e288c63006e =
# [Tempo + Trânsito Sintético] Buscando melhor ponto de embarque...
#   ✅ Melhor embarque : nó 505552907
#      Caminhada       : 159 m
#      Tempo carro     : 33.9 min (com trânsito sintético)
#      Nós expandidos  : 67
#
# 📍 Mapa — Melhor rota por TEMPO (trânsito sintético):
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f52640d6879f4c6da05a5fda6f0bf073 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f52640d6879f4c6da05a5fda6f0bf073&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f52640d6879f4c6da05a5fda6f0bf073 = L.map(
#                 &quot;map_f52640d6879f4c6da05a5fda6f0bf073&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8df461ad740acb70366ad98149e029b1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8df461ad740acb70366ad98149e029b1.addTo(map_f52640d6879f4c6da05a5fda6f0bf073);
#
#
#             var marker_f785b0f8f6a369e2e57b1eb6c74abe40 = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_f52640d6879f4c6da05a5fda6f0bf073);
#
#
#             var icon_3326df17459cded2a75cd3d91c1346c5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0376dd25a8fc2ad37e7f5f287b89b74d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8da1bd29615d960e1c4462f8514810b7 = $(`&lt;div id=&quot;html_8da1bd29615d960e1c4462f8514810b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 159 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_0376dd25a8fc2ad37e7f5f287b89b74d.setContent(html_8da1bd29615d960e1c4462f8514810b7);
#
#
#
#         marker_f785b0f8f6a369e2e57b1eb6c74abe40.bindPopup(popup_0376dd25a8fc2ad37e7f5f287b89b74d)
#         ;
#
#
#
#
#             marker_f785b0f8f6a369e2e57b1eb6c74abe40.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f785b0f8f6a369e2e57b1eb6c74abe40.setIcon(icon_3326df17459cded2a75cd3d91c1346c5);
#
#
#             var marker_b04555cfa69e8700bea9dff2cdd83256 = L.marker(
#                 [-5.8140402, -35.2056243],
#                 {
# }
#             ).addTo(map_f52640d6879f4c6da05a5fda6f0bf073);
#
#
#             var icon_d20031d4a298da0d249e819ee2ccc5a2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9bd1ef094044328552274070c74dda4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55600cb060a798c9be0dce3d5cf1e722 = $(`&lt;div id=&quot;html_55600cb060a798c9be0dce3d5cf1e722&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;Dijkstra Bidirecional — Tempo&lt;br&gt;33.9 min de carro&lt;/div&gt;`)[0];
#                 popup_9bd1ef094044328552274070c74dda4f.setContent(html_55600cb060a798c9be0dce3d5cf1e722);
#
#
#
#         marker_b04555cfa69e8700bea9dff2cdd83256.bindPopup(popup_9bd1ef094044328552274070c74dda4f)
#         ;
#
#
#
#
#             marker_b04555cfa69e8700bea9dff2cdd83256.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_b04555cfa69e8700bea9dff2cdd83256.setIcon(icon_d20031d4a298da0d249e819ee2ccc5a2);
#
#
#             var marker_19f4f36f926cbf3f7a9048b10e99e9e2 = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_f52640d6879f4c6da05a5fda6f0bf073);
#
#
#             var icon_d59751d882cfe42345d94d378c192a27 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5d9bc607606267d0f6db8673d4aa41bf = L.po
# [Tempo Livre] Buscando melhor ponto de embarque (Sem trânsito)...
#   ✅ Melhor embarque : nó 505552907
#      Caminhada       : 159 m
#      Tempo carro     : 6.5 min (SEM trânsito)
#      Nós expandidos  : 7228
#
# 📍 Mapa — Melhor rota por TEMPO (Sem trânsito):
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab00a61f1ecfb716255ad480139bd95c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab00a61f1ecfb716255ad480139bd95c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab00a61f1ecfb716255ad480139bd95c = L.map(
#                 &quot;map_ab00a61f1ecfb716255ad480139bd95c&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45463b81f643bc9f7b1a0f8a9d0e720f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45463b81f643bc9f7b1a0f8a9d0e720f.addTo(map_ab00a61f1ecfb716255ad480139bd95c);
#
#
#             var marker_9bd9db61b4b3b0cc70d0dee4a8518caf = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_ab00a61f1ecfb716255ad480139bd95c);
#
#
#             var icon_879fd90993289552c48d2a7d8e1a8259 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1e2a1f7aad3b49b725d8fda0c54af217 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18e043f63d7e9d72a5034bdbe39638ff = $(`&lt;div id=&quot;html_18e043f63d7e9d72a5034bdbe39638ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 159 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_1e2a1f7aad3b49b725d8fda0c54af217.setContent(html_18e043f63d7e9d72a5034bdbe39638ff);
#
#
#
#         marker_9bd9db61b4b3b0cc70d0dee4a8518caf.bindPopup(popup_1e2a1f7aad3b49b725d8fda0c54af217)
#         ;
#
#
#
#
#             marker_9bd9db61b4b3b0cc70d0dee4a8518caf.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_9bd9db61b4b3b0cc70d0dee4a8518caf.setIcon(icon_879fd90993289552c48d2a7d8e1a8259);
#
#
#             var marker_ab175e3c6a5fbb1131998ee8388c5792 = L.marker(
#                 [-5.8140402, -35.2056243],
#                 {
# }
#             ).addTo(map_ab00a61f1ecfb716255ad480139bd95c);
#
#
#             var icon_9b9089e4bc3e9e221eeaee8488bd280b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0dfb2616ae3ac1cd6822e2912e9a356b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fdf9c537546ff95e7dc88243f86d637 = $(`&lt;div id=&quot;html_2fdf9c537546ff95e7dc88243f86d637&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;Dijkstra Bidirecional — Tempo Livre&lt;br&gt;6.5 min de carro&lt;/div&gt;`)[0];
#                 popup_0dfb2616ae3ac1cd6822e2912e9a356b.setContent(html_2fdf9c537546ff95e7dc88243f86d637);
#
#
#
#         marker_ab175e3c6a5fbb1131998ee8388c5792.bindPopup(popup_0dfb2616ae3ac1cd6822e2912e9a356b)
#         ;
#
#
#
#
#             marker_ab175e3c6a5fbb1131998ee8388c5792.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_ab175e3c6a5fbb1131998ee8388c5792.setIcon(icon_9b9089e4bc3e9e221eeaee8488bd280b);
#
#
#             var marker_4721320f8fc70825d6867110c92a13e3 = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_ab00a61f1ecfb716255ad480139bd95c);
#
#
#             var icon_9d1b6ecfb470a0915d63a566692d537e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_41002b06cb85bbef81ecede2bf7370ec =

# %% [markdown]
# #Rota sem caminhada

# %%
# ---- CASO 4: SEM CAMINHADA (P = A)
print("=== CASO 4: Rota direta A → B (sem caminhada) ===")

# Dist
cam4_d, custo4_d, nexp4_d = dijkstra_heap(grafo_dist, no_A, no_B)
print(f"  Distância : {custo4_d/1000:.2f} km  |  Nós expandidos: {nexp4_d}")

# Tempo sem trânsito
cam4_tl, custo4_tl, nexp4_tl = dijkstra_heap(grafo_tempo_livre, no_A, no_B)
print(f"  Tempo livre: {custo4_tl/60:.1f} min  |  Nós expandidos: {nexp4_tl}")

# Tempo c/ trânsito sintético
cam4_t, custo4_t, nexp4_t = dijkstra_heap(grafo_tempo, no_A, no_B)
print(f"  Tempo trânsito: {custo4_t/60:.1f} min  |  Nós expandidos: {nexp4_t}")

# Mapa
mapa_caso4 = plotar_mapa_ridesmart(
    G_osm, coord_A, no_A, cam4_t, coord_B,
    0, custo4_t, "Caso 4 — Sem caminhada", otimizar_por='tempo'
)
display(mapa_caso4)
# Out:
# === CASO 4: Rota direta A → B (sem caminhada) ===
#   Distância : 7.40 km  |  Nós expandidos: 8414
#   Tempo livre: 6.7 min  |  Nós expandidos: 7254
#   Tempo trânsito: 35.3 min  |  Nós expandidos: 7756
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8036a77639b1a51b6dd5cb1d3667487 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8036a77639b1a51b6dd5cb1d3667487&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8036a77639b1a51b6dd5cb1d3667487 = L.map(
#                 &quot;map_a8036a77639b1a51b6dd5cb1d3667487&quot;,
#                 {
#                     center: [-5.8121199, -35.2057242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_97150eeea747c3a98126e84528f0302e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_97150eeea747c3a98126e84528f0302e.addTo(map_a8036a77639b1a51b6dd5cb1d3667487);
#
#
#             var marker_e2fdebdacd9c73333d7e0a641b03eba1 = L.marker(
#                 [-5.8121199, -35.2057242],
#                 {
# }
#             ).addTo(map_a8036a77639b1a51b6dd5cb1d3667487);
#
#
#             var icon_1459385f827c52f32c2c1758e5297c8d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3be2b0c2487e63b3a6dcd7b566ebb1a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fea244a579ce3e1265325e1befed3480 = $(`&lt;div id=&quot;html_fea244a579ce3e1265325e1befed3480&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origem&lt;/b&gt;&lt;br&gt;Caminhe 0 m até o ponto verde.&lt;/div&gt;`)[0];
#                 popup_3be2b0c2487e63b3a6dcd7b566ebb1a2.setContent(html_fea244a579ce3e1265325e1befed3480);
#
#
#
#         marker_e2fdebdacd9c73333d7e0a641b03eba1.bindPopup(popup_3be2b0c2487e63b3a6dcd7b566ebb1a2)
#         ;
#
#
#
#
#             marker_e2fdebdacd9c73333d7e0a641b03eba1.bindTooltip(
#                 `&lt;div&gt;
#                      Origem (A)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_e2fdebdacd9c73333d7e0a641b03eba1.setIcon(icon_1459385f827c52f32c2c1758e5297c8d);
#
#
#             var marker_1407ea3fdb8b0a4d5e29a6cbd63d9904 = L.marker(
#                 [-5.8127001, -35.2051263],
#                 {
# }
#             ).addTo(map_a8036a77639b1a51b6dd5cb1d3667487);
#
#
#             var icon_fabb2fc7ab3c910c34e88e6aaa234d46 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cac5c18cb70fd1173583f801a6764de7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc5d033b7718b99a9da8f6af5649a3c2 = $(`&lt;div id=&quot;html_cc5d033b7718b99a9da8f6af5649a3c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ponto de Embarque&lt;/b&gt;&lt;br&gt;Caso 4 — Sem caminhada&lt;br&gt;35.3 min de carro&lt;/div&gt;`)[0];
#                 popup_cac5c18cb70fd1173583f801a6764de7.setContent(html_cc5d033b7718b99a9da8f6af5649a3c2);
#
#
#
#         marker_1407ea3fdb8b0a4d5e29a6cbd63d9904.bindPopup(popup_cac5c18cb70fd1173583f801a6764de7)
#         ;
#
#
#
#
#             marker_1407ea3fdb8b0a4d5e29a6cbd63d9904.bindTooltip(
#                 `&lt;div&gt;
#                      Embarque (P)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_1407ea3fdb8b0a4d5e29a6cbd63d9904.setIcon(icon_fabb2fc7ab3c910c34e88e6aaa234d46);
#
#
#             var marker_de8d68125cf0914db578090c6b66cfbe = L.marker(
#                 [-5.8659941, -35.1858902],
#                 {
# }
#             ).addTo(map_a8036a77639b1a51b6dd5cb1d3667487);
#
#
#             var icon_b16af6748bb0fc29f2b61594664fe988 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2b4ace19ebf3a663b937d4b23268e140 = L.popup({
#   &

# %% [markdown]
# #Ganho comparativo:

# %%
# ---------- CASO 5: GANHO AO CAMINHAR
print("=== CASO 5: Ganho obtido ao caminhar ===")

# Reuse os resultados já calculados nas seções anteriores.
# Exemplo com Dijkstra Heap, métrica de tempo com trânsito:
custo_sem_caminhada = custo4_t          # tempo direto A→B
custo_com_caminhada = custo_t           # melhor P encontrado pelo Heap
dist_caminhada      = cam_t             # metros caminhados até P

ganho_tempo = custo_sem_caminhada - custo_com_caminhada  # segundos

print(f"  Sem caminhada (A direto): {custo_sem_caminhada/60:.1f} min")
print(f"  Com caminhada ({dist_caminhada:.0f} m):   {custo_com_caminhada/60:.1f} min")

if ganho_tempo > 0:
    print(f"  ✅ Caminhar economizou {ganho_tempo/60:.1f} min")
elif ganho_tempo < 0:
    print(f"  ❌ Caminhar custou {-ganho_tempo/60:.1f} min a mais — não valeu a pena")
else:
    print(f"  ➡️  Caminhar não fez diferença")

ganho_dist = custo4_d - custo_d
print(f"\n  [Distância] Sem caminhada: {custo4_d/1000:.2f} km  →  Com caminhada: {custo_d/1000:.2f} km  (Δ {ganho_dist/1000:+.2f} km)")
# Out:
# === CASO 5: Ganho obtido ao caminhar ===
#   Sem caminhada (A direto): 35.3 min
#   Com caminhada (159 m):   33.9 min
#   ✅ Caminhar economizou 1.4 min
#
#   [Distância] Sem caminhada: 7.40 km  →  Com caminhada: 7.24 km  (Δ +0.16 km)
